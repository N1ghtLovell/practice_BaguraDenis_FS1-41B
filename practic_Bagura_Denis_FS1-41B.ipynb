# %% [markdown]
# # Практика

# %% [markdown]
# Выполнил студент: Багура Денис \
# Группа: ФН1-41Б

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize = (8, 8))

#зададим аргумент и модуль комплексного числа
phi = np.linspace(0, 2*np.pi, 400)
rho = 1.2*abs(np.cos(7/2 * phi))
z = rho * (np.cos(phi) + 1j * np.sin(phi))

#построение исходной розы
plt.plot(z.real, z.imag, color = 'green', linewidth = 0.8)

plt.xlabel("Re(z)")
plt.ylabel("Im(z)")

#построение границы исходной розы
phi_1 = np.linspace(0, 2*np.pi, 400)
rho = 1.2*abs(np.cos(7/2 * phi_1))
z = rho * (np.cos(phi_1) + 1j * np.sin(phi_1))
plt.plot(z.real, z.imag, color = 'purple', linewidth = 3)

#построение координатной сетки до отображения
y = np.linspace(1.5, 1.5, 50)
x = np.linspace(-1.5, 1.5, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

y = np.linspace(1, 1, 50)
x = np.linspace(-1.5, 1.5, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

y = np.linspace(0.5, 0.5, 50)
x = np.linspace(-1.5, 1.5, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

y = np.linspace(0, 0, 50)
x = np.linspace(-1.5, 1.5, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

y = np.linspace(-0.5, -0.5, 50)
x = np.linspace(-1.5, 1.5, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

y = np.linspace(-1, -1, 50)
x = np.linspace(-1.5, 1.5, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

y = np.linspace(-1.5, -1.5, 50)
x = np.linspace(-1.5, 1.5, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

y = np.linspace(1.5, 1.5, 50)
x = np.linspace(-1.5, 1.5, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(1, 1, 50)
y = np.linspace(-1.5, 1.5, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(0.5, 0.5, 50)
y = np.linspace(-1.5, 1.5, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(0, 0, 50)
y = np.linspace(-1.5, 1.5, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-0.5, -0.5, 50)
y = np.linspace(-1.5, 1.5, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1, -1, 50)
y = np.linspace(-1.5, 1.5, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

x = np.linspace(-1.5, -1.5, 50)
y = np.linspace(-1.5, 1.5, 50)
plt.plot(x, y, color = 'black', linewidth = 0.3)

plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize = (8, 8))

#модуль, аргумент и отображение комплексного числа
phi = np.linspace(0, 2*np.pi, 400)
rho = 1.2*abs(np.cos(7/2 * phi))
z = rho * (np.cos(phi) + 1j * np.sin(phi))
f = (3*z-1)/(3-z)

#построение образа розы
plt.plot(f.real, f.imag, color = 'blue', linewidth = 0.8)

#построение образа границы розы
phi = np.linspace(0, 2*np.pi, 400)
rho = 1.2*abs(np.cos(7/2 * phi))
z = rho * (np.cos(phi) + 1j * np.sin(phi))
plt.plot(f.real, f.imag, color = 'red', linewidth = 3)

#построение новой координатной сетки
y = np.linspace(2.5, 2.5, 250)
x = np.linspace(-5, 5, 250)
z = x + 1j * y
f = (3*z-1)/(3-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

y = np.linspace(2, 2, 250)
x = np.linspace(-5, 5, 250)
z = x + 1j * y
f = (3*z-1)/(3-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

y = np.linspace(1.5, 1.5, 250)
x = np.linspace(-5, 5, 250)
z = x + 1j * y
f = (3*z-1)/(3-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

y = np.linspace(1, 1, 250)
x = np.linspace(-5, 5, 250)
z = x + 1j * y
f = (3*z-1)/(3-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

y = np.linspace(0.5, 0.5, 250)
x = np.linspace(-5, 5, 250)
z = x + 1j * y
f = (3*z-1)/(3-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

y = np.linspace(0, 0, 250)
x = np.linspace(-5, 5, 250)
z = x + 1j * y
f = (3*z-1)/(3-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

y = np.linspace(-0.5, -0.5, 250)
x = np.linspace(-5, 5, 250)
z = x + 1j * y
f = (3*z-1)/(3-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

y = np.linspace(-1, -1, 250)
x = np.linspace(-5, 5, 250)
z = x + 1j * y
f = (3*z-1)/(3-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

y = np.linspace(-1.5, -1.5, 250)
x = np.linspace(-5, 5, 250)
z = x + 1j * y
f = (3*z-1)/(3-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

y = np.linspace(-2, -2, 250)
x = np.linspace(-5, 5, 250)
z = x + 1j * y
f = (3*z-1)/(3-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

y = np.linspace(-2.5, -2.5, 250)
x = np.linspace(-5, 5, 250)
z = x + 1j * y
f = (3*z-1)/(3-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(1, 1, 250)
y = np.linspace(-5, 5, 250)
z = x + 1j * y
f = (3*z-1)/(3-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(0.5, 0.5, 250)
y = np.linspace(-5, 5, 250)
z = x + 1j * y
f = (3*z-1)/(3-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(0, 0, 250)
y = np.linspace(-5, 5, 250)
z = x + 1j * y
f = (3*z-1)/(3-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-0.5, -0.5, 250)
y = np.linspace(-5, 5, 250)
z = x + 1j * y
f = (3*z-1)/(3-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-1, -1, 250)
y = np.linspace(-5, 5, 250)
z = x + 1j * y
f = (3*z-1)/(3-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-1.5, -1.5, 250)
y = np.linspace(-5, 5, 250)
z = x + 1j * y
f = (3*z-1)/(3-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)

x = np.linspace(-2, -2, 250)
y = np.linspace(-5, 5, 250)
z = x + 1j * y
f = (3*z-1)/(3-z)
plt.plot(f.real, f.imag, color = 'black', linewidth = 0.3)


plt.xlabel("Re(f(z))")
plt.ylabel("Im(f(z))")
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize = (7, 7))

#построение меньшей розы
phi = np.linspace(0, 10*np.pi, 1500)
rho_1 = 0.2*abs(np.cos(2/5 * phi))
z = rho_1 * (np.cos(phi) + 1j * np.sin(phi))
plt.plot(z.real, z.imag, color = 'red', linewidth = 1.5)

#построение большей розы
phi = np.linspace(0, 14*np.pi, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi))
z = rho_2 * (np.cos(phi) + 1j * np.sin(phi))
plt.plot(z.real, z.imag, color = 'orange', linewidth = 1.5)

#построение границ области
phi_1 = np.linspace(-np.pi/6, np.pi/6, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_1))
z = rho_2 * (np.cos(phi_1) + 1j * np.sin(phi_1))
plt.plot(z.real, z.imag, color = 'black', linewidth = 3)

phi_2 = np.linspace(-np.pi/6 + 14*np.pi/3, np.pi/6 + 14*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_2))
z = rho_2 * (np.cos(phi_2) + 1j * np.sin(phi_2))
plt.plot(z.real, z.imag, color = 'black', linewidth = 3)

phi_3 = np.linspace(-np.pi/6 + 28*np.pi/3, np.pi/6 + 28*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_3))
z = rho_2 * (np.cos(phi_3) + 1j * np.sin(phi_3))
plt.plot(z.real, z.imag, color = 'black', linewidth = 3)

phi_4 = np.linspace(-np.pi/6 + 21*np.pi/3, np.pi/6 + 21*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_4))
z = rho_2 * (np.cos(phi_4) + 1j * np.sin(phi_4))
plt.plot(z.real, z.imag, color = 'black', linewidth = 3)

phi_5 = np.linspace(-np.pi/6 + 35*np.pi/3, np.pi/6 + 35*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_5))
z = rho_2 * (np.cos(phi_5) + 1j * np.sin(phi_5))
plt.plot(z.real, z.imag, color = 'black', linewidth = 3)

phi_6 = np.linspace(-np.pi/6 + 7*np.pi/3, np.pi/6 + 7*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_6))
z = rho_2 * (np.cos(phi_6) + 1j * np.sin(phi_6))
plt.plot(z.real, z.imag, color = 'black', linewidth = 3)

phi_7 = np.linspace(-np.pi/4, np.pi/4, 800)
rho_2 = 0.2*abs(np.cos(2/5 * phi_7))
z = rho_2 * (np.cos(phi_7) + 1j * np.sin(phi_7))
plt.plot(z.real, z.imag, color = 'black', linewidth = 3)

phi_8 = np.linspace(-np.pi/4 + 5*np.pi, np.pi/4 + 5*np.pi, 800)
rho_2 = 0.2*abs(np.cos(2/5 * phi_8))
z = rho_2 * (np.cos(phi_8) + 1j * np.sin(phi_8))
plt.plot(z.real, z.imag, color = 'black', linewidth = 3)

phi_9 = np.linspace(-np.pi/4 + 2.5*np.pi, np.pi/4 + 2.5*np.pi, 800)
rho_2 = 0.2*abs(np.cos(2/5 * phi_9))
z = rho_2 * (np.cos(phi_9) + 1j * np.sin(phi_9))
plt.plot(z.real, z.imag, color = 'black', linewidth = 3)

phi_10 = np.linspace(-np.pi/4 + 7.5*np.pi, np.pi/4 + 7.5*np.pi, 800)
rho_2 = 0.2*abs(np.cos(2/5 * phi_10))
z = rho_2 * (np.cos(phi_10) + 1j * np.sin(phi_10))
plt.plot(z.real, z.imag, color = 'black', linewidth = 3)

plt.xlim(-0.9, 0.9)
plt.ylim(-0.9, 0.9)

plt.show()

# %% [markdown]
# Для наглядности оставим только границу области.

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize = (7, 7))

#раскраска области
phi_1 = np.linspace(-np.pi/6, np.pi/6, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_1))
rho_1 = 0.2*abs(np.cos(2/5 * phi_1))
lines = np.linspace(rho_1, rho_2, 800)
z = lines * ((np.cos(phi_1) + 1j * np.sin(phi_1)))
plt.plot(z.real, z.imag, color = 'red')

phi_2 = np.linspace(-np.pi/6 + 14*np.pi/3, np.pi/6 + 14*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_2))
rho_1 = 0.2*abs(np.cos(2/5 * phi_2))
lines = np.linspace(rho_1, rho_2, 800)
z = lines * ((np.cos(phi_2) + 1j * np.sin(phi_2)))
plt.plot(z.real, z.imag, color = 'orange')

phi_3 = np.linspace(-np.pi/6 + 28*np.pi/3, np.pi/6 + 28*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_3))
rho_1 = 0.2*abs(np.cos(2/5 * phi_3))
lines = np.linspace(rho_1, rho_2, 800)
z = lines * ((np.cos(phi_3) + 1j * np.sin(phi_3)))
plt.plot(z.real, z.imag, color = 'yellow')

phi_4 = np.linspace(-np.pi/6 + 21*np.pi/3, np.pi/6 + 21*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_4))
rho_1 = 0.2*abs(np.cos(2/5 * phi_4))
lines = np.linspace(rho_1, rho_2, 800)
z = lines * ((np.cos(phi_4) + 1j * np.sin(phi_4)))
plt.plot(z.real, z.imag, color = 'green')

phi_5 = np.linspace(-np.pi/6 + 35*np.pi/3, np.pi/6 + 35*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_5))
rho_1 = 0.2*abs(np.cos(2/5 * phi_5))
lines = np.linspace(rho_1, rho_2, 800)
z = lines * ((np.cos(phi_5) + 1j * np.sin(phi_5)))
plt.plot(z.real, z.imag, color = 'blue')

phi_6 = np.linspace(-np.pi/6 + 7*np.pi/3, np.pi/6 + 7*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_6))
rho_1 = 0.2*abs(np.cos(2/5 * phi_6))
lines = np.linspace(rho_1, rho_2, 800)
z = lines * ((np.cos(phi_6) + 1j * np.sin(phi_6)))
plt.plot(z.real, z.imag, color = 'purple')


#уберем лишнюю раскраску внутри меньшей розы
phi_7 = np.linspace(-np.pi/4, np.pi/4, 800)
rho_1 = 0.2*abs(np.cos(2/5 * phi_7))
lines = np.linspace(0, rho_1, 800)
z = lines * ((np.cos(phi_7) + 1j * np.sin(phi_7)))
plt.plot(z.real, z.imag, color = 'white')

phi_8 = np.linspace(-np.pi/4 + 5*np.pi, np.pi/4 + 5*np.pi, 800)
rho_1 = 0.2*abs(np.cos(2/5 * phi_8))
lines = np.linspace(0, rho_1, 800)
z = lines * ((np.cos(phi_8) + 1j * np.sin(phi_8)))
plt.plot(z.real, z.imag, color = 'white')

phi_9 = np.linspace(-np.pi/4 + 2.5*np.pi, np.pi/4 + 2.5*np.pi, 800)
rho_1 = 0.2*abs(np.cos(2/5 * phi_9))
lines = np.linspace(0, rho_1, 800)
z = lines * ((np.cos(phi_9) + 1j * np.sin(phi_9)))
plt.plot(z.real, z.imag, color = 'white')

phi_10 = np.linspace(-np.pi/4 + 7.5*np.pi, np.pi/4 + 7.5*np.pi, 800)
rho_1 = 0.2*abs(np.cos(2/5 * phi_10))
lines = np.linspace(0, rho_1, 800)
z = lines * ((np.cos(phi_10) + 1j * np.sin(phi_10)))
plt.plot(z.real, z.imag, color = 'white')


phi_1 = np.linspace(-np.pi/6, np.pi/6, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_1))
z = rho_2 * (np.cos(phi_1) + 1j * np.sin(phi_1))
plt.plot(z.real, z.imag, color = 'black', linewidth = 3)

phi_2 = np.linspace(-np.pi/6 + 14*np.pi/3, np.pi/6 + 14*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_2))
z = rho_2 * (np.cos(phi_2) + 1j * np.sin(phi_2))
plt.plot(z.real, z.imag, color = 'black', linewidth = 3)

phi_3 = np.linspace(-np.pi/6 + 28*np.pi/3, np.pi/6 + 28*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_3))
z = rho_2 * (np.cos(phi_3) + 1j * np.sin(phi_3))
plt.plot(z.real, z.imag, color = 'black', linewidth = 3)

phi_4 = np.linspace(-np.pi/6 + 21*np.pi/3, np.pi/6 + 21*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_4))
z = rho_2 * (np.cos(phi_4) + 1j * np.sin(phi_4))
plt.plot(z.real, z.imag, color = 'black', linewidth = 3)

phi_5 = np.linspace(-np.pi/6 + 35*np.pi/3, np.pi/6 + 35*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_5))
z = rho_2 * (np.cos(phi_5) + 1j * np.sin(phi_5))
plt.plot(z.real, z.imag, color = 'black', linewidth = 3)

phi_6 = np.linspace(-np.pi/6 + 7*np.pi/3, np.pi/6 + 7*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_6))
z = rho_2 * (np.cos(phi_6) + 1j * np.sin(phi_6))
plt.plot(z.real, z.imag, color = 'black', linewidth = 3)

phi_7 = np.linspace(-np.pi/4, np.pi/4, 800)
rho_1 = 0.2*abs(np.cos(2/5 * phi_7))
z = rho_1 * (np.cos(phi_7) + 1j * np.sin(phi_7))
plt.plot(z.real, z.imag, color = 'black', linewidth = 3)

phi_8 = np.linspace(-np.pi/4 + 5*np.pi, np.pi/4 + 5*np.pi, 800)
rho_1 = 0.2*abs(np.cos(2/5 * phi_8))
z = rho_1 * (np.cos(phi_8) + 1j * np.sin(phi_8))
plt.plot(z.real, z.imag, color = 'black', linewidth = 3)

phi_9 = np.linspace(-np.pi/4 + 2.5*np.pi, np.pi/4 + 2.5*np.pi, 800)
rho_1 = 0.2*abs(np.cos(2/5 * phi_9))
z = rho_1 * (np.cos(phi_9) + 1j * np.sin(phi_9))
plt.plot(z.real, z.imag, color = 'black', linewidth = 3)

phi_10 = np.linspace(-np.pi/4 + 7.5*np.pi, np.pi/4 + 7.5*np.pi, 800)
rho_1 = 0.2*abs(np.cos(2/5 * phi_10))
z = rho_1 * (np.cos(phi_10) + 1j * np.sin(phi_10))
plt.plot(z.real, z.imag, color = 'black', linewidth = 3)

plt.xlim(-0.9, 0.9)
plt.ylim(-0.9, 0.9)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize = (7, 7))

#построение образа меньшей розы
phi = np.linspace(0, 10*np.pi, 1500)
rho_1 = 0.2*abs(np.cos(2/5 * phi))
z = rho_1 * (np.cos(phi) + 1j * np.sin(phi))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'red', linewidth = 1.5)

#построение образа большей розы
phi = np.linspace(0, 14*np.pi, 2500)
rho_2 = 0.8*abs(np.cos(3/7 * phi))
z = rho_2 * (np.cos(phi) + 1j * np.sin(phi))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'orange', linewidth = 1.5)

#построение образа границы области
phi_1 = np.linspace(-np.pi/6, np.pi/6, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_1))
z = rho_2 * (np.cos(phi_1) + 1j * np.sin(phi_1))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 3)

phi_2 = np.linspace(-np.pi/6 + 14*np.pi/3, np.pi/6 + 14*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_2))
z = rho_2 * (np.cos(phi_2) + 1j * np.sin(phi_2))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 3)

phi_3 = np.linspace(-np.pi/6 + 28*np.pi/3, np.pi/6 + 28*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_3))
z = rho_2 * (np.cos(phi_3) + 1j * np.sin(phi_3))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 3)

phi_4 = np.linspace(-np.pi/6 + 21*np.pi/3, np.pi/6 + 21*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_4))
z = rho_2 * (np.cos(phi_4) + 1j * np.sin(phi_4))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 3)

phi_5 = np.linspace(-np.pi/6 + 35*np.pi/3, np.pi/6 + 35*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_5))
z = rho_2 * (np.cos(phi_5) + 1j * np.sin(phi_5))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 3)

phi_6 = np.linspace(-np.pi/6 + 7*np.pi/3, np.pi/6 + 7*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_6))
z = rho_2 * (np.cos(phi_6) + 1j * np.sin(phi_6))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 3)

phi_7 = np.linspace(-np.pi/4, np.pi/4, 800)
rho_2 = 0.2*abs(np.cos(2/5 * phi_7))
z = rho_2 * (np.cos(phi_7) + 1j * np.sin(phi_7))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 3)

phi_8 = np.linspace(-np.pi/4 + 5*np.pi, np.pi/4 + 5*np.pi, 800)
rho_2 = 0.2*abs(np.cos(2/5 * phi_8))
z = rho_2 * (np.cos(phi_8) + 1j * np.sin(phi_8))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 3)

phi_9 = np.linspace(-np.pi/4 + 2.5*np.pi, np.pi/4 + 2.5*np.pi, 800)
rho_2 = 0.2*abs(np.cos(2/5 * phi_9))
z = rho_2 * (np.cos(phi_9) + 1j * np.sin(phi_9))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 3)

phi_10 = np.linspace(-np.pi/4 + 7.5*np.pi, np.pi/4 + 7.5*np.pi, 800)
rho_2 = 0.2*abs(np.cos(2/5 * phi_10))
z = rho_2 * (np.cos(phi_10) + 1j * np.sin(phi_10))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 3)

plt.xlim(-0.5, 5.5)
plt.ylim(-3, 3)

plt.show()

# %% [markdown]
# Для наглядности оставим только границу образа области.

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize = (7, 7))

#раскраска образа области
phi_1 = np.linspace(-np.pi/6, np.pi/6, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_1))
rho_1 = 0.2*abs(np.cos(2/5 * phi_1))
lines = np.linspace(rho_1, rho_2, 800)
z = lines * ((np.cos(phi_1) + 1j * np.sin(phi_1)))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'red')

phi_2 = np.linspace(-np.pi/6 + 14*np.pi/3, np.pi/6 + 14*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_2))
rho_1 = 0.2*abs(np.cos(2/5 * phi_2))
lines = np.linspace(rho_1, rho_2, 800)
z = lines * ((np.cos(phi_2) + 1j * np.sin(phi_2)))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'orange')

phi_3 = np.linspace(-np.pi/6 + 28*np.pi/3, np.pi/6 + 28*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_3))
rho_1 = 0.2*abs(np.cos(2/5 * phi_3))
lines = np.linspace(rho_1, rho_2, 800)
z = lines * ((np.cos(phi_3) + 1j * np.sin(phi_3)))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'yellow')

phi_4 = np.linspace(-np.pi/6 + 21*np.pi/3, np.pi/6 + 21*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_4))
rho_1 = 0.2*abs(np.cos(2/5 * phi_4))
lines = np.linspace(rho_1, rho_2, 800)
z = lines * ((np.cos(phi_4) + 1j * np.sin(phi_4)))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'green')

phi_5 = np.linspace(-np.pi/6 + 35*np.pi/3, np.pi/6 + 35*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_5))
rho_1 = 0.2*abs(np.cos(2/5 * phi_5))
lines = np.linspace(rho_1, rho_2, 800)
z = lines * ((np.cos(phi_5) + 1j * np.sin(phi_5)))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'blue')

phi_6 = np.linspace(-np.pi/6 + 7*np.pi/3, np.pi/6 + 7*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_6))
rho_1 = 0.2*abs(np.cos(2/5 * phi_6))
lines = np.linspace(rho_1, rho_2, 800)
z = lines * ((np.cos(phi_6) + 1j * np.sin(phi_6)))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'purple')


#уберем лишнюю раскраску внутри меньшей розы
phi_7 = np.linspace(-np.pi/4, np.pi/4, 800)
rho_1 = 0.2*abs(np.cos(2/5 * phi_7))
lines = np.linspace(0, rho_1, 800)
z = lines * ((np.cos(phi_7) + 1j * np.sin(phi_7)))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'white')

phi_8 = np.linspace(-np.pi/4 + 5*np.pi, np.pi/4 + 5*np.pi, 800)
rho_1 = 0.2*abs(np.cos(2/5 * phi_8))
lines = np.linspace(0, rho_1, 800)
z = lines * ((np.cos(phi_8) + 1j * np.sin(phi_8)))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'white')

phi_9 = np.linspace(-np.pi/4 + 2.5*np.pi, np.pi/4 + 2.5*np.pi, 800)
rho_1 = 0.2*abs(np.cos(2/5 * phi_9))
lines = np.linspace(0, rho_1, 800)
z = lines * ((np.cos(phi_9) + 1j * np.sin(phi_9)))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'white')

phi_10 = np.linspace(-np.pi/4 + 7.5*np.pi, np.pi/4 + 7.5*np.pi, 800)
rho_1 = 0.2*abs(np.cos(2/5 * phi_10))
lines = np.linspace(0, rho_1, 800)
z = lines * ((np.cos(phi_10) + 1j * np.sin(phi_10)))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'white')


phi_1 = np.linspace(-np.pi/6, np.pi/6, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_1))
z = rho_2 * (np.cos(phi_1) + 1j * np.sin(phi_1))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 3)

phi_2 = np.linspace(-np.pi/6 + 14*np.pi/3, np.pi/6 + 14*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_2))
z = rho_2 * (np.cos(phi_2) + 1j * np.sin(phi_2))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 3)

phi_3 = np.linspace(-np.pi/6 + 28*np.pi/3, np.pi/6 + 28*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_3))
z = rho_2 * (np.cos(phi_3) + 1j * np.sin(phi_3))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 3)

phi_4 = np.linspace(-np.pi/6 + 21*np.pi/3, np.pi/6 + 21*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_4))
z = rho_2 * (np.cos(phi_4) + 1j * np.sin(phi_4))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 3)

phi_5 = np.linspace(-np.pi/6 + 35*np.pi/3, np.pi/6 + 35*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_5))
z = rho_2 * (np.cos(phi_5) + 1j * np.sin(phi_5))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 3)

phi_6 = np.linspace(-np.pi/6 + 7*np.pi/3, np.pi/6 + 7*np.pi/3, 800)
rho_2 = 0.8*abs(np.cos(3/7 * phi_6))
z = rho_2 * (np.cos(phi_6) + 1j * np.sin(phi_6))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 3)

phi_7 = np.linspace(-np.pi/4, np.pi/4, 800)
rho_2 = 0.2*abs(np.cos(2/5 * phi_7))
z = rho_2 * (np.cos(phi_7) + 1j * np.sin(phi_7))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 3)

phi_8 = np.linspace(-np.pi/4 + 5*np.pi, np.pi/4 + 5*np.pi, 800)
rho_2 = 0.2*abs(np.cos(2/5 * phi_8))
z = rho_2 * (np.cos(phi_8) + 1j * np.sin(phi_8))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 3)

phi_9 = np.linspace(-np.pi/4 + 2.5*np.pi, np.pi/4 + 2.5*np.pi, 800)
rho_2 = 0.2*abs(np.cos(2/5 * phi_9))
z = rho_2 * (np.cos(phi_9) + 1j * np.sin(phi_9))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 3)

phi_10 = np.linspace(-np.pi/4 + 7.5*np.pi, np.pi/4 + 7.5*np.pi, 800)
rho_2 = 0.2*abs(np.cos(2/5 * phi_10))
z = rho_2 * (np.cos(phi_10) + 1j * np.sin(phi_10))
g = np.exp(2*z)
plt.plot(g.real, g.imag, color = 'black', linewidth = 3)

plt.xlim(-0.5, 5.5)
plt.ylim(-3, 3)

plt.show()
